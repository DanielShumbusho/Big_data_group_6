# %%
#Palindrome function
def isPalindrome(s):
    s = s.lower().replace(" ", "")
    return s == s[::-1]
isPalindrome("race car")

# %%
#Text combine question
def combine ():
    t1 = input("Enter a text: ")
    t2 = input("Enter a text2: ")
    combine = t1 + t2
    print("Characters in the text: ")
    for char in combine:
        print(char)

combine()
